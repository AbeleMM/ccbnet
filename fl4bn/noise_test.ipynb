# %%
import numpy as np
from pgmpy.factors.discrete.CPD import TabularCPD
from pgmpy.models import BayesianNetwork
from pgmpy.sampling import BayesianModelSampling
from pgmpy.utils import get_example_model
from typing import cast
from util import get_in_out_nodes, calc_accuracy

SEED = 42


def add_noise(model: BayesianNetwork, std_dev = 0.05, r_seed: int | None = None) -> None:
    mean = 0.0
    mn = mean - 3 * std_dev
    mx = mean + 3 * std_dev
    rng = np.random.default_rng(r_seed)
    for cpd in cast(list[TabularCPD], model.get_cpds()):
        noise = rng.normal(mean, std_dev, cpd.values.shape)
        noise = np.clip(noise, mn, mx)
        cpd.values += noise
        cpd.normalize(inplace=True)


def check_noisiest_allowed(
        model_name: str,
        step = 0.05,
        tol = 2.0,
        r_seed: int | None = None) -> None:
    model = get_example_model(model_name)
    evidence_vars, query_vars = get_in_out_nodes(model)
    test_samples = BayesianModelSampling(model).forward_sample(
        size=2000, seed=r_seed, show_progress=False
    )

    accs_orig = calc_accuracy(test_samples, model, evidence_vars, query_vars)
    acc_orig = sum(accs_orig.values()) / len(accs_orig)

    std_dev = 0.0
    diff = 0.0

    # Note: accuracy does not degrade linearly as step increases
    while diff < tol:
        std_dev += step
        noisy_model = model.copy()
        add_noise(noisy_model, std_dev, r_seed)
        accs_noisy = calc_accuracy(test_samples, noisy_model, evidence_vars, query_vars)
        acc_noisy = sum(accs_noisy.values()) / len(accs_noisy)
        diff = abs(acc_orig - acc_noisy)

    std_dev -= step

    if not std_dev:
        print("No suitable noise threshold found.")
        return

    noisy_model = model.copy()
    add_noise(noisy_model, std_dev, r_seed)
    accs_noisy = calc_accuracy(test_samples, noisy_model, evidence_vars, query_vars)
    acc_noisy = sum(accs_noisy.values()) / len(accs_noisy)
    diff = abs(acc_orig - acc_noisy)
    print("Standard Deviation:", std_dev, "|", "Difference:", acc_orig - acc_noisy)
    print()


    for var in evidence_vars + query_vars:
        print("Original")
        print(model.get_cpds(var))
        print("Noisy")
        print(noisy_model.get_cpds(var))
        print()

# %%
check_noisiest_allowed("asia", r_seed=SEED)
# Out:
# Standard Deviation: 0.5499999999999999 | Difference: 0.0
#
# Original
# +-----------+------+
# | asia(yes) | 0.01 |
# +-----------+------+
# | asia(no)  | 0.99 |
# +-----------+------+
# Noisy
# +-----------+----------+
# | asia(yes) | 0.298176 |
# +-----------+----------+
# | asia(no)  | 0.701824 |
# +-----------+----------+
#
# Original
# +------------+-----+
# | smoke(yes) | 0.5 |
# +------------+-----+
# | smoke(no)  | 0.5 |
# +------------+-----+
# Noisy
# +------------+---------+
# | smoke(yes) | 0.53072 |
# +------------+---------+
# | smoke(no)  | 0.46928 |
# +------------+---------+
#
# Original
# +-----------+-------------+------------+
# | either    | either(yes) | either(no) |
# +-----------+-------------+------------+
# | xray(yes) | 0.98        | 0.05       |
# +-----------+-------------+------------+
# | xray(no)  | 0.02        | 0.95       |
# +-----------+-------------+------------+
# Noisy
# +-----------+---------------------+---------------------+
# | either    | either(yes)         | either(no)          |
# +-----------+---------------------+---------------------+
# | xray(yes) | 0.660577149877733   | -0.3388346983881699 |
# +-----------+---------------------+---------------------+
# | xray(no)  | 0.33942285012226714 | 1.3388346983881698  |
# +-----------+---------------------+---------------------+
#
# Original
# +-----------+-------------+------------+-------------+------------+
# | bronc     | bronc(yes)  | bronc(yes) | bronc(no)   | bronc(no)  |
# +-----------+-------------+------------+-------------+------------+
# | either    | either(yes) | either(no) | either(yes) | either(no) |
# +-----------+-------------+------------+-------------+------------+
# | dysp(yes) | 0.9         | 0.8        | 0.7         | 0.1        |
# +-----------+-------------+------------+-------------+------------+
# | dysp(no)  | 0.1         | 0.2        | 0.3         | 0.9        |
# +-----------+-------------+------------+-------------+------------+
# Noisy
# +-----------+--------------------+-----+---------------------+
# | bronc     | bronc(yes)         | ... | bronc(no)           |
# +-----------+--------------------+-----+---------------------+
# | either    | either(yes)        | ... | either(no)          |
# +-----------+--------------------+-----+---------------------+
# | dysp(yes) | 0.6244041300108943 | ... | -0.3207954746503248 |
# +-----------+--------------------+-----+---------------------+
# | dysp(no)  | 0.3755958699891057 | ... | 1.3207954746503248  |
# +-----------+--------------------+-----+---------------------+

# %%
check_noisiest_allowed("alarm", r_seed=SEED)
# Out:
# Standard Deviation: 0.10000000000000002 | Difference: 0.5318181818181671
#
# Original
# +--------------------+-----+
# | HYPOVOLEMIA(TRUE)  | 0.2 |
# +--------------------+-----+
# | HYPOVOLEMIA(FALSE) | 0.8 |
# +--------------------+-----+
# Noisy
# +--------------------+----------+
# | HYPOVOLEMIA(TRUE)  | 0.109966 |
# +--------------------+----------+
# | HYPOVOLEMIA(FALSE) | 0.890034 |
# +--------------------+----------+
#
# Original
# +------------------+------+
# | LVFAILURE(TRUE)  | 0.05 |
# +------------------+------+
# | LVFAILURE(FALSE) | 0.95 |
# +------------------+------+
# Noisy
# +------------------+-----------+
# | LVFAILURE(TRUE)  | -0.128219 |
# +------------------+-----------+
# | LVFAILURE(FALSE) |  1.12822  |
# +------------------+-----------+
#
# Original
# +---------------------+------+
# | ERRLOWOUTPUT(TRUE)  | 0.05 |
# +---------------------+------+
# | ERRLOWOUTPUT(FALSE) | 0.95 |
# +---------------------+------+
# Noisy
# +---------------------+----------+
# | ERRLOWOUTPUT(TRUE)  | 0.160822 |
# +---------------------+----------+
# | ERRLOWOUTPUT(FALSE) | 0.839178 |
# +---------------------+----------+
#
# Original
# +------------------+-----+
# | ERRCAUTER(TRUE)  | 0.1 |
# +------------------+-----+
# | ERRCAUTER(FALSE) | 0.9 |
# +------------------+-----+
# Noisy
# +------------------+------------+
# | ERRCAUTER(TRUE)  | -0.0303035 |
# +------------------+------------+
# | ERRCAUTER(FALSE) |  1.0303    |
# +------------------+------------+
#
# Original
# +---------------------+-----+
# | INSUFFANESTH(TRUE)  | 0.1 |
# +---------------------+-----+
# | INSUFFANESTH(FALSE) | 0.9 |
# +---------------------+-----+
# Noisy
# +---------------------+----------+
# | INSUFFANESTH(TRUE)  | 0.193562 |
# +---------------------+----------+
# | INSUFFANESTH(FALSE) | 0.806438 |
# +---------------------+----------+
#
# Original
# +--------------------+------+
# | ANAPHYLAXIS(TRUE)  | 0.01 |
# +--------------------+------+
# | ANAPHYLAXIS(FALSE) | 0.99 |
# +--------------------+------+
# Noisy
# +--------------------+-----------+
# | ANAPHYLAXIS(TRUE)  | 0.0436836 |
# +--------------------+-----------+
# | ANAPHYLAXIS(FALSE) | 0.956316  |
# +--------------------+-----------+
#
# Original
# +-------------------+------+
# | KINKEDTUBE(TRUE)  | 0.04 |
# +-------------------+------+
# | KINKEDTUBE(FALSE) | 0.96 |
# +-------------------+------+
# Noisy
# +-------------------+----------+
# | KINKEDTUBE(TRUE)  | 0.175979 |
# +-------------------+----------+
# | KINKEDTUBE(FALSE) | 0.824021 |
# +-------------------+----------+
#
# Original
# +--------------+------+
# | FIO2(LOW)    | 0.05 |
# +--------------+------+
# | FIO2(NORMAL) | 0.95 |
# +--------------+------+
# Noisy
# +--------------+------------+
# | FIO2(LOW)    | -0.0034257 |
# +--------------+------------+
# | FIO2(NORMAL) |  1.00343   |
# +--------------+------------+
#
# Original
# +--------------------+------+
# | PULMEMBOLUS(TRUE)  | 0.01 |
# +--------------------+------+
# | PULMEMBOLUS(FALSE) | 0.99 |
# +--------------------+------+
# Noisy
# +--------------------+----------+
# | PULMEMBOLUS(TRUE)  | 0.103502 |
# +--------------------+----------+
# | PULMEMBOLUS(FALSE) | 0.896498 |
# +--------------------+----------+
#
# Original
# +------------------------+------+
# | INTUBATION(NORMAL)     | 0.92 |
# +------------------------+------+
# | INTUBATION(ESOPHAGEAL) | 0.03 |
# +------------------------+------+
# | INTUBATION(ONESIDED)   | 0.05 |
# +------------------------+------+
# Noisy
# +------------------------+-----------+
# | INTUBATION(NORMAL)     | 0.818973  |
# +------------------------+-----------+
# | INTUBATION(ESOPHAGEAL) | 0.110677  |
# +------------------------+-----------+
# | INTUBATION(ONESIDED)   | 0.0703498 |
# +------------------------+-----------+
#
# Original
# +-------------------+-----+
# | DISCONNECT(TRUE)  | 0.1 |
# +-------------------+-----+
# | DISCONNECT(FALSE) | 0.9 |
# +-------------------+-----+
# Noisy
# +-------------------+---------+
# | DISCONNECT(TRUE)  | 0.21638 |
# +-------------------+---------+
# | DISCONNECT(FALSE) | 0.78362 |
# +-------------------+---------+
#
# Original
# +-------------------+------+
# | MINVOLSET(LOW)    | 0.05 |
# +-------------------+------+
# | MINVOLSET(NORMAL) | 0.9  |
# +-------------------+------+
# | MINVOLSET(HIGH)   | 0.05 |
# +-------------------+------+
# Noisy
# +-------------------+-----------+
# | MINVOLSET(LOW)    | 0.0313806 |
# +-------------------+-----------+
# | MINVOLSET(NORMAL) | 0.744657  |
# +-------------------+-----------+
# | MINVOLSET(HIGH)   | 0.223962  |
# +-------------------+-----------+
#
# Original
# +----------------+-----------------+------------------+
# | LVFAILURE      | LVFAILURE(TRUE) | LVFAILURE(FALSE) |
# +----------------+-----------------+------------------+
# | HISTORY(TRUE)  | 0.9             | 0.01             |
# +----------------+-----------------+------------------+
# | HISTORY(FALSE) | 0.1             | 0.99             |
# +----------------+-----------------+------------------+
# Noisy
# +----------------+-----------------------+---------------------+
# | LVFAILURE      | LVFAILURE(TRUE)       | LVFAILURE(FALSE)    |
# +----------------+-----------------------+---------------------+
# | HISTORY(TRUE)  | 1.0553456903394656    | -0.1598346814967978 |
# +----------------+-----------------------+---------------------+
# | HISTORY(FALSE) | -0.055345690339465466 | 1.159834681496798   |
# +----------------+-----------------------+---------------------+
#
# Original
# +-------------+-----------------+--------------------+------------------+
# | LVEDVOLUME  | LVEDVOLUME(LOW) | LVEDVOLUME(NORMAL) | LVEDVOLUME(HIGH) |
# +-------------+-----------------+--------------------+------------------+
# | CVP(LOW)    | 0.95            | 0.04               | 0.01             |
# +-------------+-----------------+--------------------+------------------+
# | CVP(NORMAL) | 0.04            | 0.95               | 0.29             |
# +-------------+-----------------+--------------------+------------------+
# | CVP(HIGH)   | 0.01            | 0.01               | 0.7              |
# +-------------+-----------------+--------------------+------------------+
# Noisy
# +-------------+-----+------------------------+
# | LVEDVOLUME  | ... | LVEDVOLUME(HIGH)       |
# +-------------+-----+------------------------+
# | CVP(LOW)    | ... | -0.0017701054203467694 |
# +-------------+-----+------------------------+
# | CVP(NORMAL) | ... | 0.2962517042166834     |
# +-------------+-----+------------------------+
# | CVP(HIGH)   | ... | 0.7055184012036635     |
# +-------------+-----+------------------------+
#
# Original
# +--------------+-----------------+--------------------+------------------+
# | LVEDVOLUME   | LVEDVOLUME(LOW) | LVEDVOLUME(NORMAL) | LVEDVOLUME(HIGH) |
# +--------------+-----------------+--------------------+------------------+
# | PCWP(LOW)    | 0.95            | 0.04               | 0.01             |
# +--------------+-----------------+--------------------+------------------+
# | PCWP(NORMAL) | 0.04            | 0.95               | 0.04             |
# +--------------+-----------------+--------------------+------------------+
# | PCWP(HIGH)   | 0.01            | 0.01               | 0.95             |
# +--------------+-----------------+--------------------+------------------+
# Noisy
# +--------------+-----+---------------------+
# | LVEDVOLUME   | ... | LVEDVOLUME(HIGH)    |
# +--------------+-----+---------------------+
# | PCWP(LOW)    | ... | 0.07196518002718638 |
# +--------------+-----+---------------------+
# | PCWP(NORMAL) | ... | -0.2202236702790892 |
# +--------------+-----+---------------------+
# | PCWP(HIGH)   | ... | 1.1482584902519029  |
# +--------------+-----+---------------------+
#
# Original
# +--------------+--------------------+-----+---------------------+
# | ERRLOWOUTPUT | ERRLOWOUTPUT(TRUE) | ... | ERRLOWOUTPUT(FALSE) |
# +--------------+--------------------+-----+---------------------+
# | HR           | HR(LOW)            | ... | HR(HIGH)            |
# +--------------+--------------------+-----+---------------------+
# | HRBP(LOW)    | 0.98               | ... | 0.01                |
# +--------------+--------------------+-----+---------------------+
# | HRBP(NORMAL) | 0.01               | ... | 0.01                |
# +--------------+--------------------+-----+---------------------+
# | HRBP(HIGH)   | 0.01               | ... | 0.98                |
# +--------------+--------------------+-----+---------------------+
# Noisy
# +--------------+-----+---------------------+
# | ERRLOWOUTPUT | ... | ERRLOWOUTPUT(FALSE) |
# +--------------+-----+---------------------+
# | HR           | ... | HR(HIGH)            |
# +--------------+-----+---------------------+
# | HRBP(LOW)    | ... | 0.04988447009629759 |
# +--------------+-----+---------------------+
# | HRBP(NORMAL) | ... | 0.03098573323387922 |
# +--------------+-----+---------------------+
# | HRBP(HIGH)   | ... | 0.9191297966698232  |
# +--------------+-----+---------------------+
#
# Original
# +---------------+-----------------+-----+------------------+
# | ERRCAUTER     | ERRCAUTER(TRUE) | ... | ERRCAUTER(FALSE) |
# +---------------+-----------------+-----+------------------+
# | HR            | HR(LOW)         | ... | HR(HIGH)         |
# +---------------+-----------------+-----+------------------+
# | HREKG(LOW)    | 0.3333333       | ... | 0.01             |
# +---------------+-----------------+-----+------------------+
# | HREKG(NORMAL) | 0.3333333       | ... | 0.01             |
# +---------------+-----------------+-----+------------------+
# | HREKG(HIGH)   | 0.3333333       | ... | 0.98             |
# +---------------+-----------------+-----+------------------+
# Noisy
# +---------------+-----+---------------------+
# | ERRCAUTER     | ... | ERRCAUTER(FALSE)    |
# +---------------+-----+---------------------+
# | HR            | ... | HR(HIGH)            |
# +---------------+-----+---------------------+
# | HREKG(LOW)    | ... | 0.13585496665917282 |
# +---------------+-----+---------------------+
# | HREKG(NORMAL) | ... | 0.04710020725951315 |
# +---------------+-----+---------------------+
# | HREKG(HIGH)   | ... | 0.817044826081314   |
# +---------------+-----+---------------------+
#
# Original
# +---------------+-----------------+-----+------------------+
# | ERRCAUTER     | ERRCAUTER(TRUE) | ... | ERRCAUTER(FALSE) |
# +---------------+-----------------+-----+------------------+
# | HR            | HR(LOW)         | ... | HR(HIGH)         |
# +---------------+-----------------+-----+------------------+
# | HRSAT(LOW)    | 0.3333333       | ... | 0.01             |
# +---------------+-----------------+-----+------------------+
# | HRSAT(NORMAL) | 0.3333333       | ... | 0.01             |
# +---------------+-----------------+-----+------------------+
# | HRSAT(HIGH)   | 0.3333333       | ... | 0.98             |
# +---------------+-----------------+-----+------------------+
# Noisy
# +---------------+-----+--------------------+
# | ERRCAUTER     | ... | ERRCAUTER(FALSE)   |
# +---------------+-----+--------------------+
# | HR            | ... | HR(HIGH)           |
# +---------------+-----+--------------------+
# | HRSAT(LOW)    | ... | 0.1627907794042551 |
# +---------------+-----+--------------------+
# | HRSAT(NORMAL) | ... | -0.171619731351227 |
# +---------------+-----+--------------------+
# | HRSAT(HIGH)   | ... | 1.0088289519469718 |
# +---------------+-----+--------------------+
#
# Original
# +----------------+----------------+-----+----------------+
# | ARTCO2         | ARTCO2(LOW)    | ... | ARTCO2(HIGH)   |
# +----------------+----------------+-----+----------------+
# | VENTLUNG       | VENTLUNG(ZERO) | ... | VENTLUNG(HIGH) |
# +----------------+----------------+-----+----------------+
# | EXPCO2(ZERO)   | 0.97           | ... | 0.01           |
# +----------------+----------------+-----+----------------+
# | EXPCO2(LOW)    | 0.01           | ... | 0.01           |
# +----------------+----------------+-----+----------------+
# | EXPCO2(NORMAL) | 0.01           | ... | 0.01           |
# +----------------+----------------+-----+----------------+
# | EXPCO2(HIGH)   | 0.01           | ... | 0.97           |
# +----------------+----------------+-----+----------------+
# Noisy
# +----------------+-----+----------------------+
# | ARTCO2         | ... | ARTCO2(HIGH)         |
# +----------------+-----+----------------------+
# | VENTLUNG       | ... | VENTLUNG(HIGH)       |
# +----------------+-----+----------------------+
# | EXPCO2(ZERO)   | ... | 0.016989248720362757 |
# +----------------+-----+----------------------+
# | EXPCO2(LOW)    | ... | -0.02029538902072705 |
# +----------------+-----+----------------------+
# | EXPCO2(NORMAL) | ... | 0.23332864163100533  |
# +----------------+-----+----------------------+
# | EXPCO2(HIGH)   | ... | 0.7699774986693589   |
# +----------------+-----+----------------------+
#
# Original
# +----------------+-----+----------------------+
# | INTUBATION     | ... | INTUBATION(ONESIDED) |
# +----------------+-----+----------------------+
# | VENTLUNG       | ... | VENTLUNG(HIGH)       |
# +----------------+-----+----------------------+
# | MINVOL(ZERO)   | ... | 0.01                 |
# +----------------+-----+----------------------+
# | MINVOL(LOW)    | ... | 0.01                 |
# +----------------+-----+----------------------+
# | MINVOL(NORMAL) | ... | 0.01                 |
# +----------------+-----+----------------------+
# | MINVOL(HIGH)   | ... | 0.97                 |
# +----------------+-----+----------------------+
# Noisy
# +----------------+-----+----------------------+
# | INTUBATION     | ... | INTUBATION(ONESIDED) |
# +----------------+-----+----------------------+
# | VENTLUNG       | ... | VENTLUNG(HIGH)       |
# +----------------+-----+----------------------+
# | MINVOL(ZERO)   | ... | 0.05570070040577337  |
# +----------------+-----+----------------------+
# | MINVOL(LOW)    | ... | 0.07439088194070176  |
# +----------------+-----+----------------------+
# | MINVOL(NORMAL) | ... | -0.07533018261113397 |
# +----------------+-----+----------------------+
# | MINVOL(HIGH)   | ... | 0.9452386002646589   |
# +----------------+-----+----------------------+
#
# Original
# +-------------+-------------------+--------------------+
# | PULMEMBOLUS | PULMEMBOLUS(TRUE) | PULMEMBOLUS(FALSE) |
# +-------------+-------------------+--------------------+
# | PAP(LOW)    | 0.01              | 0.05               |
# +-------------+-------------------+--------------------+
# | PAP(NORMAL) | 0.19              | 0.9                |
# +-------------+-------------------+--------------------+
# | PAP(HIGH)   | 0.8               | 0.05               |
# +-------------+-------------------+--------------------+
# Noisy
# +-------------+-----------------------+----------------------+
# | PULMEMBOLUS | PULMEMBOLUS(TRUE)     | PULMEMBOLUS(FALSE)   |
# +-------------+-----------------------+----------------------+
# | PAP(LOW)    | -0.037259565471107266 | 0.08804319937783399  |
# +-------------+-----------------------+----------------------+
# | PAP(NORMAL) | 0.33432109063050774   | 1.0714619037892117   |
# +-------------+-----------------------+----------------------+
# | PAP(HIGH)   | 0.7029384748405996    | -0.15950510316704555 |
# +-------------+-----------------------+----------------------+
#
# Original
# +---------------+-----+----------------------+
# | INTUBATION    | ... | INTUBATION(ONESIDED) |
# +---------------+-----+----------------------+
# | KINKEDTUBE    | ... | KINKEDTUBE(FALSE)    |
# +---------------+-----+----------------------+
# | VENTTUBE      | ... | VENTTUBE(HIGH)       |
# +---------------+-----+----------------------+
# | PRESS(ZERO)   | ... | 0.01                 |
# +---------------+-----+----------------------+
# | PRESS(LOW)    | ... | 0.01                 |
# +---------------+-----+----------------------+
# | PRESS(NORMAL) | ... | 0.01                 |
# +---------------+-----+----------------------+
# | PRESS(HIGH)   | ... | 0.97                 |
# +---------------+-----+----------------------+
# Noisy
# +---------------+-----+-----------------------+
# | INTUBATION    | ... | INTUBATION(ONESIDED)  |
# +---------------+-----+-----------------------+
# | KINKEDTUBE    | ... | KINKEDTUBE(FALSE)     |
# +---------------+-----+-----------------------+
# | VENTTUBE      | ... | VENTTUBE(HIGH)        |
# +---------------+-----+-----------------------+
# | PRESS(ZERO)   | ... | 0.12034519707209596   |
# +---------------+-----+-----------------------+
# | PRESS(LOW)    | ... | 0.03613358144767058   |
# +---------------+-----+-----------------------+
# | PRESS(NORMAL) | ... | -0.030234129809997182 |
# +---------------+-----+-----------------------+
# | PRESS(HIGH)   | ... | 0.8737553512902306    |
# +---------------+-----+-----------------------+
#
# Original
# +------------+----------+-----+-------------+-----------+
# | CO         | CO(LOW)  | ... | CO(HIGH)    | CO(HIGH)  |
# +------------+----------+-----+-------------+-----------+
# | TPR        | TPR(LOW) | ... | TPR(NORMAL) | TPR(HIGH) |
# +------------+----------+-----+-------------+-----------+
# | BP(LOW)    | 0.98     | ... | 0.05        | 0.01      |
# +------------+----------+-----+-------------+-----------+
# | BP(NORMAL) | 0.01     | ... | 0.2         | 0.09      |
# +------------+----------+-----+-------------+-----------+
# | BP(HIGH)   | 0.01     | ... | 0.75        | 0.9       |
# +------------+----------+-----+-------------+-----------+
# Noisy
# +------------+-----+---------------------+
# | CO         | ... | CO(HIGH)            |
# +------------+-----+---------------------+
# | TPR        | ... | TPR(HIGH)           |
# +------------+-----+---------------------+
# | BP(LOW)    | ... | 0.1144128216402714  |
# +------------+-----+---------------------+
# | BP(NORMAL) | ... | 0.04269995125545344 |
# +------------+-----+---------------------+
# | BP(HIGH)   | ... | 0.8428872271042752  |
# +------------+-----+---------------------+

# %%
check_noisiest_allowed("child", r_seed=SEED)
# Out:
# Standard Deviation: 0.10000000000000002 | Difference: 1.9571428571428626
#
# Original
# +--------------------+-----+
# | BirthAsphyxia(yes) | 0.1 |
# +--------------------+-----+
# | BirthAsphyxia(no)  | 0.9 |
# +--------------------+-----+
# Noisy
# +--------------------+-----------+
# | BirthAsphyxia(yes) | 0.0979508 |
# +--------------------+-----------+
# | BirthAsphyxia(no)  | 0.902049  |
# +--------------------+-----------+
#
# Original
# +----------------+----------+---------+
# | LVH            | LVH(yes) | LVH(no) |
# +----------------+----------+---------+
# | LVHreport(yes) | 0.9      | 0.05    |
# +----------------+----------+---------+
# | LVHreport(no)  | 0.1      | 0.95    |
# +----------------+----------+---------+
# Noisy
# +----------------+----------------------+---------------------+
# | LVH            | LVH(yes)             | LVH(no)             |
# +----------------+----------------------+---------------------+
# | LVHreport(yes) | 1.1028765955893982   | 0.04808060729247888 |
# +----------------+----------------------+---------------------+
# | LVHreport(no)  | -0.10287659558939835 | 0.9519193927075211  |
# +----------------+----------------------+---------------------+
#
# Original
# +-------------------+-----+---------------------+
# | HypDistrib        | ... | HypDistrib(Unequal) |
# +-------------------+-----+---------------------+
# | HypoxiaInO2       | ... | HypoxiaInO2(Severe) |
# +-------------------+-----+---------------------+
# | LowerBodyO2(<5)   | ... | 0.6                 |
# +-------------------+-----+---------------------+
# | LowerBodyO2(5-12) | ... | 0.35                |
# +-------------------+-----+---------------------+
# | LowerBodyO2(12+)  | ... | 0.05                |
# +-------------------+-----+---------------------+
# Noisy
# +-------------------+-----+----------------------+
# | HypDistrib        | ... | HypDistrib(Unequal)  |
# +-------------------+-----+----------------------+
# | HypoxiaInO2       | ... | HypoxiaInO2(Severe)  |
# +-------------------+-----+----------------------+
# | LowerBodyO2(<5)   | ... | 0.5169970151978382   |
# +-------------------+-----+----------------------+
# | LowerBodyO2(5-12) | ... | 0.4579892875853224   |
# +-------------------+-----+----------------------+
# | LowerBodyO2(12+)  | ... | 0.025013697216839267 |
# +-------------------+-----+----------------------+
#
# Original
# +-------------+-------------------+-----+---------------------+
# | HypoxiaInO2 | HypoxiaInO2(Mild) | ... | HypoxiaInO2(Severe) |
# +-------------+-------------------+-----+---------------------+
# | RUQO2(<5)   | 0.1               | ... | 0.5                 |
# +-------------+-------------------+-----+---------------------+
# | RUQO2(5-12) | 0.3               | ... | 0.4                 |
# +-------------+-------------------+-----+---------------------+
# | RUQO2(12+)  | 0.6               | ... | 0.1                 |
# +-------------+-------------------+-----+---------------------+
# Noisy
# +-------------+-----+----------------------+
# | HypoxiaInO2 | ... | HypoxiaInO2(Severe)  |
# +-------------+-----+----------------------+
# | RUQO2(<5)   | ... | 0.6080193388711963   |
# +-------------+-----+----------------------+
# | RUQO2(5-12) | ... | 0.3318286688596958   |
# +-------------+-----+----------------------+
# | RUQO2(12+)  | ... | 0.060151992269107876 |
# +-------------+-----+----------------------+
#
# Original
# +------------------+-------------+----------+-----------+
# | CO2              | CO2(Normal) | CO2(Low) | CO2(High) |
# +------------------+-------------+----------+-----------+
# | CO2Report(<7.5)  | 0.9         | 0.9      | 0.1       |
# +------------------+-------------+----------+-----------+
# | CO2Report(>=7.5) | 0.1         | 0.1      | 0.9       |
# +------------------+-------------+----------+-----------+
# Noisy
# +------------------+-----+---------------------+
# | CO2              | ... | CO2(High)           |
# +------------------+-----+---------------------+
# | CO2Report(<7.5)  | ... | 0.12398682835183121 |
# +------------------+-----+---------------------+
# | CO2Report(>=7.5) | ... | 0.8760131716481687  |
# +------------------+-----+---------------------+
#
# Original
# +------------------------+-----+----------------------+
# | ChestXray              | ... | ChestXray(Asy/Patch) |
# +------------------------+-----+----------------------+
# | XrayReport(Normal)     | ... | 0.08                 |
# +------------------------+-----+----------------------+
# | XrayReport(Oligaemic)  | ... | 0.02                 |
# +------------------------+-----+----------------------+
# | XrayReport(Plethoric)  | ... | 0.1                  |
# +------------------------+-----+----------------------+
# | XrayReport(Grd_Glass)  | ... | 0.1                  |
# +------------------------+-----+----------------------+
# | XrayReport(Asy/Patchy) | ... | 0.7                  |
# +------------------------+-----+----------------------+
# Noisy
# +------------------------+-----+-----------------------+
# | ChestXray              | ... | ChestXray(Asy/Patch)  |
# +------------------------+-----+-----------------------+
# | XrayReport(Normal)     | ... | 0.1530309774087197    |
# +------------------------+-----+-----------------------+
# | XrayReport(Oligaemic)  | ... | -0.09591217041020209  |
# +------------------------+-----+-----------------------+
# | XrayReport(Plethoric)  | ... | -0.001353552111171647 |
# +------------------------+-----+-----------------------+
# | XrayReport(Grd_Glass)  | ... | 0.2126739975476675    |
# +------------------------+-----+-----------------------+
# | XrayReport(Asy/Patchy) | ... | 0.7315607475649866    |
# +------------------------+-----+-----------------------+
#
# Original
# +---------------------+---------------+--------------+
# | Grunting            | Grunting(yes) | Grunting(no) |
# +---------------------+---------------+--------------+
# | GruntingReport(yes) | 0.8           | 0.1          |
# +---------------------+---------------+--------------+
# | GruntingReport(no)  | 0.2           | 0.9          |
# +---------------------+---------------+--------------+
# Noisy
# +---------------------+---------------------+----------------------+
# | Grunting            | Grunting(yes)       | Grunting(no)         |
# +---------------------+---------------------+----------------------+
# | GruntingReport(yes) | 0.7509296927303375  | 0.010237563634424901 |
# +---------------------+---------------------+----------------------+
# | GruntingReport(no)  | 0.24907030726966248 | 0.9897624363655751   |
# +---------------------+---------------------+----------------------+
#
# Original
# +-----------------+--------------+-----+---------------+---------------+
# | Disease         | Disease(PFC) | ... | Disease(Lung) | Disease(Lung) |
# +-----------------+--------------+-----+---------------+---------------+
# | Sick            | Sick(yes)    | ... | Sick(yes)     | Sick(no)      |
# +-----------------+--------------+-----+---------------+---------------+
# | Age(0-3_days)   | 0.95         | ... | 0.9           | 0.8           |
# +-----------------+--------------+-----+---------------+---------------+
# | Age(4-10_days)  | 0.03         | ... | 0.08          | 0.15          |
# +-----------------+--------------+-----+---------------+---------------+
# | Age(11-30_days) | 0.02         | ... | 0.02          | 0.05          |
# +-----------------+--------------+-----+---------------+---------------+
# Noisy
# +-----------------+-----+---------------------+
# | Disease         | ... | Disease(Lung)       |
# +-----------------+-----+---------------------+
# | Sick            | ... | Sick(no)            |
# +-----------------+-----+---------------------+
# | Age(0-3_days)   | ... | 0.7469040676162495  |
# +-----------------+-----+---------------------+
# | Age(4-10_days)  | ... | 0.11448635489346955 |
# +-----------------+-----+---------------------+
# | Age(11-30_days) | ... | 0.13860957749028094 |
# +-----------------+-----+---------------------+
